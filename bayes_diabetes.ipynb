# %%
from sklearn.linear_model import BayesianRidge
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from numpy import sqrt

# %%
#1st attempt Using default setting
boston = load_diabetes()
x, y = boston.data, boston.target
xtrain, xtest, ytrain, ytest=train_test_split(x, y, test_size=0.2)

# %%
bay_ridge = BayesianRidge(verbose=True)
bay_ridge.fit(xtrain, ytrain)
score=bay_ridge.score(xtrain, ytrain)
print("Model score (R-squared): %.2f" % score)
# Out:
# Convergence after  9  iterations
# Model score (R-squared): 0.52

# %%
ypred = bay_ridge.predict(xtest)
mse = mean_squared_error(ytest, ypred)
print("MSE: %.2f" % mse)
print("RMSE: %.2f" % sqrt(mse))
# Out:
# MSE: 3007.41
# RMSE: 54.84

# %%
x_ax = range(len(ytest))
plt.scatter(x_ax, ytest, s=5, color="blue", label="original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
#2nd attempt with higher tolerance and lambda init
bay_ridge = BayesianRidge(n_iter=1000, verbose=True, tol=1e-9, lambda_init=2)
bay_ridge.fit(xtrain, ytrain)
score=bay_ridge.score(xtrain, ytrain)
print("Model score (R-squared): %.2f" % score)
# Out:
# Convergence after  13  iterations
# Model score (R-squared): 0.52

# %%
ypred = bay_ridge.predict(xtest)
mse = mean_squared_error(ytest, ypred)
print("MSE: %.2f" % mse)
print("RMSE: %.2f" % sqrt(mse))
# Out:
# MSE: 3395.83
# RMSE: 58.27

# %%
x_ax = range(len(ytest))
plt.scatter(x_ax, ytest, s=5, color="blue", label="original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
boston = load_diabetes()
x, y = boston.data, boston.target
xtrain, xtest, ytrain, ytest=train_test_split(x, y, test_size=0.15)

# %%
bay_ridge = BayesianRidge()
bay_ridge.fit(xtrain, ytrain)
score=bay_ridge.score(xtrain, ytrain)
print("Model score (R-squared): %.2f" % score)
# Out:
# Model score (R-squared): 0.52

# %%
ypred = bay_ridge.predict(xtest)
mse = mean_squared_error(ytest, ypred)
print("MSE: %.2f" % mse)
print("RMSE: %.2f" % sqrt(mse))
# Out:
# MSE: 3395.83
# RMSE: 58.27

# %%
x_ax = range(len(ytest))
plt.scatter(x_ax, ytest, s=5, color="blue", label="original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()
